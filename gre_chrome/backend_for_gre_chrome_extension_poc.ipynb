# %%
import pickle
import pandas as pd
import numpy as np
import os
import json
import random

# %%
refined_words = pickle.load(open('all_words_with_freq_and_meaning.pkl','rb'))
word_frame = pd.DataFrame(refined_words)

# %%
pd.set_option('display.max_rows',10000)
word_frame[word_frame.freq<100].head(800)
# Out:
#        freq         word                                            meaning
# 26    64.82     absolute                        perfect or complete or pure
# 48    24.93       accord                             concurrence of opinion
# 77    43.10      address  the place where a person or organization can b...
# 264   56.65     apparent  clearly revealed to the mind or the senses or ...
# 422   29.83         bank  financial institution that accepts deposits an...
# 433   58.69         base                      lowest support of a structure
# 468   72.06      benefit         something that aids or promotes well-being
# 494   66.21          bid                                  propose a payment
# 505   67.86       bitter         causing a sharp and acrid taste experience
# 548   88.04         bore  make a hole, especially with a pointed power o...
# 551   39.26        bound                                  confined by bonds
# 565   66.62        brave                   possessing or displaying courage
# 638   44.40         camp    temporary lodgings in the country for travelers
# 668   87.91       career  the particular occupation for which you are tr...
# 745   63.13        charm  attractiveness that interests or pleases or st...
# 763   92.38       choice                               the act of selecting
# 785   39.87        civil  of or occurring between or among citizens of t...
# 865   74.11     communal          for or by a group rather than individuals
# 929   67.59   confidence              belief in yourself and your abilities
# 1001  85.33      convene                                      meet formally
# 1002  91.48   convention                        the act of meeting formally
# 1006  51.18     converse                              carry on a discussion
# 1042  78.67       couple                         two items of the same kind
# 1044  59.10        court           an assembly to conduct judicial business
# 1075  46.86        cross  a marking that consists of lines that intersec...
# 1364  30.61      distant         separated in space or coming from far away
# 1367  80.39     distinct             constituting a separate entity or part
# 1383  89.55       divine    a clergyman or other person in religious orders
# 1419  89.78        drama  a work intended for performance by actors on a...
# 1447  93.67         earn     acquire or deserve by one's efforts or actions
# 1460  36.40      economy  the system of production and distribution and ...
# 1553  47.05       engage             consume all of one's attention or time
# 1554  84.41      engaged  having one's attention or mind or energy consumed
# 1649  48.77        exact  marked by strict and complete accordance with ...
# 1657  44.05      exclaim   utter aloud, often with surprise, horror, or joy
# 1662  44.31      execute                                      put in effect
# 1664  92.80    executive  a person responsible for the administration of...
# 1699  98.81       expose                     show; make visible or apparent
# 1748  58.41        fancy                not plain; decorative or ornamented
# 1753  63.23      fashion  the latest and most admired style in clothes o...
# 1767  64.63      feature       a prominent attribute or aspect of something
# 1801  30.41       figure               the form or shape of a person's body
# 1813  45.30       finish                            come or bring to an end
# 1817  39.34          fit           meeting adequate standards for a purpose
# 1893  34.41      forward                       at or to or toward the front
# 1980  72.50     generate                               bring into existence
# 1987  52.62       gentle        soft and mild; not harsh or stern or severe
# 2108  94.89     handsome                             pleasing in appearance
# 2119  94.64        harry  make a pillaging or destructive raid on, as in...
# 2159  47.52         hide              prevent from being seen or discovered
# 2212  34.94      husband                       a male partner in a marriage
# 2345  99.20     incident                            a single distinct event
# 2352  93.29      incline                  lower or bend, as in a nod or bow
# 2483  68.34    institute                   set up or lay the groundwork for
# 2499  90.82    intellect                       knowledge and mental ability
# 2821  96.82       marked                                  easily noticeable
# 2835  78.94         mass  the property of a body that causes it to have ...
# 2919  24.91       minute  a unit of time equal to 60 seconds or 1/60th o...
# 2977  48.21        moral       concerned with principles of right and wrong
# 3150  53.22    opportune  suitable or advantageous especially for a part...
# 3481  73.01    practical  guided by experience and observation rather th...
# 3663  89.75     purchase        acquire by means of a financial transaction
# 3732  66.10         rank                                    relative status
# 3741  68.73         rare        especially good, remarkable, or superlative
# 3797  69.54       reduce                                       make smaller
# 3807  44.49       refuse                         show unwillingness towards
# 3831  65.78    religious  having or showing belief in and reverence for ...
# 3848  69.29       render                                     give or supply
# 3896  74.20      reserve  hold back or set aside, especially for future use
# 3903  52.06      resolve                          find a solution or answer
# 4055  73.24        score  a number that expresses accomplishment in a ga...
# 4147  90.88  significant                                rich in implication
# 4182  44.64       slight                        small in quantity or degree
# 4232  23.69        sound  mechanical vibrations transmitted by an elasti...
# 4305  55.50        stock     a supply of something available for future use
# 4657  85.89        yield                                     give or supply

# %%
pickle_storage = {}
code_series = pd.qcut(word_frame.freq,8).cat.codes
word_frame.word = word_frame.word.str.capitalize()
word_frame['code'] = code_series
word_frame['difficulty'] = word_frame.code.replace({0:1,2:1,3:1,4:1,5:2,6:2,7:3})
for difficulty, df in word_frame.groupby('difficulty'):
    pickle_storage[str(difficulty)] = df[['word','meaning']].to_dict(orient='records')
pickle_storage
# Out:
# {'1': [{'word': 'Abase', 'meaning': 'cause to feel shame'},
#   {'word': 'Abash', 'meaning': 'cause to be embarrassed'},
#   {'word': 'Abate', 'meaning': 'become less in amount or intensity'},
#   {'word': 'Abbreviate', 'meaning': 'shorten'},
#   {'word': 'Aberration',
#    'meaning': 'a state or condition markedly different from the norm'},
#   {'word': 'Abet',
#    'meaning': 'assist or encourage, usually in some wrongdoing'},
#   {'word': 'Abhor', 'meaning': 'find repugnant'},
#   {'word': 'Abide', 'meaning': 'dwell'},
#   {'word': 'Abject', 'meaning': 'of the most contemptible kind'},
#   {'word': 'Abjure',
#    'meaning': 'formally reject or disavow a formerly held belief'},
#   {'word': 'Abode',
#    'meaning': 'any address at which you dwell more than temporarily'},
#   {'word': 'Abolish', 'meaning': 'do away with'},
#   {'word': 'Abominable', 'meaning': 'unequivocally detestable'},
#   {'word': 'Abominate', 'meaning': 'find repugnant'},
#   {'word': 'Aboriginal', 'meaning': 'having existed from the beginning'},
#   {'word': 'Abortive', 'meaning': 'failing to accomplish an intended result'},
#   {'word': 'Abridge', 'meaning': 'lessen, diminish, or curtail'},
#   {'word': 'Abrogate', 'meaning': 'revoke formally'},
#   {'word': 'Absolute', 'meaning': 'perfect or complete or pure'},
#   {'word': 'Absolve', 'meaning': 'grant remission of a sin to'},
#   {'word': 'Abstain',
#    'meaning': 'refrain from doing, consuming, or partaking in something'},
#   {'word': 'Abstinence',
#    'meaning': 'the trait of refraining from something, especially alcohol'},
#   {'word': 'Abstract', 'meaning': 'existing only in the mind'},
#   {'word': 'Abusive',
#    'meaning': 'characterized by physical or psychological maltreatment'},
#   {'word': 'Abyss', 'meaning': 'a bottomless gulf or pit'},
#   {'word': 'Academic',
#    'meaning': 'associated with an educational institution'},
#   {'word': 'Accede', 'meaning': "yield to another's wish or opinion"},
#   {'word': 'Accelerate', 'meaning': 'move faster'},
#   {'word': 'Accessible', 'meaning': 'capable of being reached'},
#   {'word': 'Accessory',
#    'meaning': 'a supplementary component that improves capability'},
#   {'word': 'Acclaim', 'meaning': 'enthusiastic approval'},
#   {'word': 'Accommodate', 'meaning': 'have room for; hold without crowding'},
#   {'word': 'Accomplice',
#    'meaning': 'a person who joins with another in carrying out some plan'},
#   {'word': 'Accord', 'meaning': 'concurrence of opinion'},
#   {'word': 'Accost',
#    'meaning': 'approach and speak to someone aggressively or insistently'},
#   {'word': 'Accrue', 'meaning': 'grow by addition'},
#   {'word': 'Acknowledge',
#    'meaning': 'declare to be true or admit the existence or reality of'},
#   {'word': 'Acquiesce', 'meaning': 'agree or express agreement'},
#   {'word': 'Acquiescence',
#    'meaning': 'agreement with a statement or proposal to do something'},
#   {'word': 'Acquittal', 'meaning': 'a judgment of not guilty'},
#   {'word': 'Acrid', 'meaning': 'strong and sharp, as a taste or smell'},
#   {'word': 'Actuate', 'meaning': 'put in motion'},
#   {'word': 'Acute', 'meaning': 'ending in a sharp point'},
#   {'word': 'Adamant',
#    'meaning': 'very hard native crystalline carbon valued as a gem'},
#   {'word': 'Adapt',
#    'meaning': 'make fit for, or change to suit a new purpose'},
#   {'word': 'Addiction',
#    'meaning': 'being dependent on something habit-forming '},
#   {'word': 'Address',
#    'meaning': 'the place where a person or organization can be found'},
#   {'word': 'Adduce', 'meaning': 'advance evidence for'},
#   {'word': 'Adept',
#    'meaning': 'having or showing knowledge and skill and aptitude'},
#   {'word': 'Adhere', 'meaning': 'stick to firmly'},
#   {'word': 'Adherent',
#    'meaning': 'someone who believes and helps to spread a doctrine'},
#   {'word': 'Adjacent', 'meaning': 'having a common boundary or edge'},
#   {'word': 'Adjoin', 'meaning': 'lie next to another or share a boundary'},
#   {'word': 'Adjourn', 'meaning': 'close at the end of a session'},
#   {'word': 'Adjunct',
#    'meaning': 'something added to another thing but not essential to it'},
#   {'word': 'Adjutant',
#    'meaning': 'an officer who acts as an assistant to a more senior officer'},
#   {'word': 'Admonish', 'meaning': 'scold or reprimand; take to task'},
#   {'word': 'Admonition', 'meaning': 'a firm rebuke'},
#   {'word': 'Adore', 'meaning': 'love intensely'},
#   {'word': 'Adorn',
#    'meaning': 'make more attractive, as by adding ornament or color'},
#   {'word': 'Adroit',
#    'meaning': 'quick or skillful or adept in action or thought'},
#   {'word': 'Adulterate',
#    'meaning': 'make impure by adding a foreign or inferior substance'},
#   {'word': 'Advent', 'meaning': 'arrival that has been awaited'},
#   {'word': 'Adversary', 'meaning': 'someone who offers opposition'},
#   {'word': 'Adverse', 'meaning': 'in an opposing direction'},
#   {'word': 'Adversity', 'meaning': 'a state of misfortune or affliction'},
#   {'word': 'Advert',
#    'meaning': 'a public promotion of some product or service'},
#   {'word': 'Advocacy', 'meaning': 'active support of an idea or cause'},
#   {'word': 'Advocate',
#    'meaning': 'a person who pleads for a person, cause, or idea'},
#   {'word': 'Aesthetic',
#    'meaning': 'characterized by an appreciation of beauty or good taste'},
#   {'word': 'Affable', 'meaning': 'diffusing warmth and friendliness'},
#   {'word': 'Affected', 'meaning': 'influenced'},
#   {'word': 'Affidavit', 'meaning': 'written declaration made under oath'},
#   {'word': 'Affinity',
#    'meaning': 'a natural attraction or feeling of kinship'},
#   {'word': 'Affirmation',
#    'meaning': 'the act of asserting or stating something'},
#   {'word': 'Affliction', 'meaning': 'a cause of great suffering and distress'},
#   {'word': 'Affluence', 'meaning': 'abundant wealth'},
#   {'word': 'Affront', 'meaning': 'a deliberately offensive act'},
#   {'word': 'Agenda',
#    'meaning': 'a list of matters to be taken up, as at a meeting'},
#   {'word': 'Aggregate',
#    'meaning': 'a sum total of many heterogeneous things taken together'},
#   {'word': 'Aghast', 'meaning': 'struck with fear, dread, or consternation'},
#   {'word': 'Agility',
#    'meaning': 'the gracefulness of a quick and nimble person or animal'},
#   {'word': 'Agitate', 'meaning': 'move or cause to move back and forth'},
#   {'word': 'Agitation',
#    'meaning': 'a mental state of extreme emotional disturbance'},
#   {'word': 'Airy', 'meaning': 'open to or abounding in fresh atmosphere'},
#   {'word': 'Alacrity', 'meaning': 'liveliness and eagerness'},
#   {'word': 'Alchemy',
#    'meaning': 'a pseudoscientific forerunner of chemistry in medieval times'},
#   {'word': 'Alcove', 'meaning': 'a small recess opening off a larger room'},
#   {'word': 'Alias', 'meaning': 'a name that has been assumed temporarily'},
#   {'word': 'Alienate', 'meaning': 'arouse hostility or indifference in'},
#   {'word': 'Allay', 'meaning': 'lessen the intensity of or calm'},
#   {'word': 'Allege', 'meaning': 'report or maintain'},
#   {'word': 'Allegiance',
#    'meaning': 'the act of binding yourself to a course of action'},
#   {'word': 'Allegory', 'meaning': 'a short moral story '},
#   {'word': 'Alleviate', 'meaning': 'provide physical relief, as from pain'},
#   {'word': 'Allocate',
#    'meaning': 'distribute according to a plan or set apart for a purpose'},
#   {'word': 'Alloy',
#    'meaning': 'a mixture containing two or more metallic elements'},
#   {'word': 'Allude', 'meaning': 'make an indirect reference to'},
#   {'word': 'Allure', 'meaning': 'the power to entice or attract'},
#   {'word': 'Allusion', 'meaning': 'passing reference or indirect mention'},
#   {'word': 'Alms', 'meaning': 'money or goods contributed to the poor'},
#   {'word': 'Aloft',
#    'meaning': 'at or on or to the masthead or upper rigging of a ship'},
#   {'word': 'Aloof', 'meaning': 'distant, cold, or detached in manner'},
#   {'word': 'Altercation', 'meaning': 'a noisy quarrel'},
#   {'word': 'Altruism',
#    'meaning': 'the quality of unselfish concern for the welfare of others'},
#   {'word': 'Amalgam', 'meaning': 'a combination or blend of diverse things'},
#   {'word': 'Amalgamate',
#    'meaning': 'bring or combine together or with something else'},
#   {'word': 'Amass', 'meaning': 'collect or gather'},
#   {'word': 'Ambiguous', 'meaning': 'having more than one possible meaning'},
#   {'word': 'Amble', 'meaning': 'walk leisurely'},
#   {'word': 'Ambush',
#    'meaning': 'concealing yourself and lying in wait to attack by surprise'},
#   {'word': 'Ameliorate', 'meaning': 'make better'},
#   {'word': 'Amenable', 'meaning': 'disposed or willing to comply'},
#   {'word': 'Amend', 'meaning': 'make revisions to'},
#   {'word': 'Amiable', 'meaning': 'diffusing warmth and friendliness'},
#   {'word': 'Amicable', 'meaning': 'characterized by friendship and good will'},
#   {'word': 'Amiss', 'meaning': 'in an improper or mistaken manner'},
#   {'word': 'Amity', 'meaning': 'a state of friendship and cordiality'},
#   {'word': 'Amnesty',
#    'meaning': 'a warrant granting release from punishment for an offense'},
#   {'word': 'Amorous', 'meaning': 'inclined toward or displaying love'},
#   {'word': 'Ample',
#    'meaning': 'more than enough in size or scope or capacity'},
#   {'word': 'Amplify', 'meaning': 'increase the volume of'},
#   {'word': 'Amputate', 'meaning': 'remove surgically'},
#   {'word': 'Analogous', 'meaning': 'similar or equivalent in some respects'},
#   {'word': 'Analogy',
#    'meaning': 'drawing a comparison in order to show a similarity'},
#   {'word': 'Anarchist',
#    'meaning': 'an advocate of the abolition of governments'},
#   {'word': 'Anarchy', 'meaning': 'a state of lawlessness and disorder'},
#   {'word': 'Anathema',
#    'meaning': 'a formal ecclesiastical curse accompanied by excommunication'},
#   {'word': 'Ancestry', 'meaning': 'the lineage of an individual'},
#   {'word': 'Anchor',
#    'meaning': 'a mechanical device that prevents a vessel from moving'},
#   {'word': 'Anecdote', 'meaning': 'short account of an incident'},
#   {'word': 'Anguish', 'meaning': 'extreme distress of body or mind'},
#   {'word': 'Angular',
#    'meaning': 'having straight lines and sharp points or corners'},
#   {'word': 'Animated', 'meaning': 'having life or vigor or spirit'},
#   {'word': 'Animosity',
#    'meaning': 'a feeling of ill will arousing active hostility'},
#   {'word': 'Annals',
#    'meaning': 'a chronological account of events in successive years'},
#   {'word': 'Annex', 'meaning': 'attach to'},
#   {'word': 'Annihilate', 'meaning': 'kill in large numbers'},
#   {'word': 'Annotate',
#    'meaning': 'add explanatory notes to or supply with critical comments'},
#   {'word': 'Annuity',
#    'meaning': 'income from capital investment paid regularly'},
#   {'word': 'Annul', 'meaning': 'cancel officially'},
#   {'word': 'Anoint',
#    'meaning': 'administer an oil or ointment to, often ceremonially'},
#   {'word': 'Anomaly',
#    'meaning': 'deviation from the normal or common order, form, or rule'},
#   {'word': 'Anonymity', 'meaning': 'the state of being unknown'},
#   {'word': 'Anonymous',
#    'meaning': 'having no known name or identity or known source'},
#   {'word': 'Antagonism',
#    'meaning': 'an actively expressed feeling of dislike and hostility'},
#   {'word': 'Antecede', 'meaning': 'be earlier in time; go back further'},
#   {'word': 'Antecedent',
#    'meaning': 'a preceding occurrence or cause or event'},
#   {'word': 'Anthem', 'meaning': 'a song of devotion or loyalty'},
#   {'word': 'Anthology',
#    'meaning': 'a collection of selected literary passages'},
#   {'word': 'Antidote',
#    'meaning': 'a remedy that stops or controls the effects of a poison'},
#   {'word': 'Antipathy', 'meaning': 'a feeling of intense dislike'},
#   {'word': 'Antiquated',
#    'meaning': 'so extremely old as seeming to belong to an earlier period'},
#   {'word': 'Antique',
#    'meaning': 'made in or typical of earlier times and valued for its age'},
#   {'word': 'Antiquity',
#    'meaning': 'the historic period preceding the Middle Ages in Europe'},
#   {'word': 'Antithesis', 'meaning': 'exact opposite'},
#   {'word': 'Antler',
#    'meaning': 'deciduous horn of a member of the deer family'},
#   {'word': 'Anvil',
#    'meaning': 'a heavy block on which hot metals are shaped by hammering'},
#   {'word': 'Apathy', 'meaning': 'an absence of emotion or enthusiasm'},
#   {'word': 'Ape',
#    'meaning': 'any of various primates with short tails or no tail at all'},
#   {'word': 'Aperture', 'meaning': 'a natural opening in something'},
#   {'word': 'Apex', 'meaning': 'the highest point of something'},
#   {'word': 'Apoplexy',
#    'meaning': 'a loss of consciousness from the lack of oxygen in the brain'},
#   {'word': 'Apostate',
#    'meaning': 'not faithful to religion or party or cause'},
#   {'word': 'Apothecary',
#    'meaning': 'a health professional trained in the art of preparing drugs'},
#   {'word': 'Appall', 'meaning': 'strike with disgust or revulsion'},
#   {'word': 'Apparent',
#    'meaning': 'clearly revealed to the mind or the senses or judgment'},
#   {'word': 'Apparition', 'meaning': 'a ghostly appearing figure'},
#   {'word': 'Appease', 'meaning': 'make peace with'},
#   {'word': 'Appellation',
#    'meaning': 'identifying words by which someone or something is called'},
#   {'word': 'Append', 'meaning': 'fix to; attach'},
#   {'word': 'Application',
#    'meaning': 'the action of putting something into operation'},
#   {'word': 'Appraise', 'meaning': 'consider in a comprehensive way'},
#   {'word': 'Appreciate', 'meaning': 'be fully aware of; realize fully'},
#   {'word': 'Apprehend', 'meaning': 'anticipate with dread or anxiety'},
#   {'word': 'Apprehensive',
#    'meaning': 'in fear or dread of possible evil or harm'},
#   {'word': 'Apprise', 'meaning': 'inform somebody of something'},
#   {'word': 'Approbation', 'meaning': 'official acceptance or agreement'},
#   {'word': 'Appropriate',
#    'meaning': 'suitable for a particular person, place, or situation'},
#   {'word': 'Aptitude', 'meaning': 'inherent ability'},
#   {'word': 'Arable', 'meaning': 'capable of being farmed productively'},
#   {'word': 'Arbiter',
#    'meaning': 'someone chosen to judge and decide a disputed issue'},
#   {'word': 'Arbitrary',
#    'meaning': 'based on or subject to individual discretion or preference'},
#   {'word': 'Arbitrate',
#    'meaning': 'act between parties with a view to reconciling differences'},
#   {'word': 'Arcade',
#    'meaning': 'a structure composed of arches supported by columns'},
#   {'word': 'Arch',
#    'meaning': 'a curved masonry construction for spanning an opening'},
#   {'word': 'Archaeology',
#    'meaning': 'the branch of anthropology that studies prehistoric people'},
#   {'word': 'Archaic',
#    'meaning': 'so extremely old as seeming to belong to an earlier period'},
#   {'word': 'Archipelago',
#    'meaning': 'a group of many islands in a large body of water'},
#   {'word': 'Archives',
#    'meaning': 'collection of records especially about an institution'},
#   {'word': 'Ardor', 'meaning': 'feelings of great warmth and intensity'},
#   {'word': 'Arduous',
#    'meaning': 'characterized by effort to the point of exhaustion'},
#   {'word': 'Aria', 'meaning': 'an elaborate song for solo voice'},
#   {'word': 'Arid', 'meaning': 'lacking sufficient water or rainfall'},
#   {'word': 'Aristocracy',
#    'meaning': 'a privileged class holding hereditary titles'},
#   {'word': 'Armada', 'meaning': 'a large fleet'},
#   {'word': 'Aromatic', 'meaning': 'having a strong pleasant odor'},
#   {'word': 'Arraign', 'meaning': 'accuse of a wrong or an inadequacy'},
#   {'word': 'Array', 'meaning': 'an impressive display or assortment'},
#   {'word': 'Arrears', 'meaning': 'the state of being behind in payments'},
#   {'word': 'Arrogance',
#    'meaning': 'overbearing pride evidenced by a superior manner'},
#   {'word': 'Arsenal',
#    'meaning': 'all the weapons and equipment that a country has'},
#   {'word': 'Artery',
#    'meaning': 'a blood vessel that carries blood from the heart to the body'},
#   {'word': 'Artful', 'meaning': 'not straightforward or candid'},
#   {'word': 'Articulate', 'meaning': 'express or state clearly'},
#   {'word': 'Artifice', 'meaning': 'the use of deception or trickery'},
#   {'word': 'Artisan',
#    'meaning': 'a skilled worker who practices some trade or handicraft'},
#   {'word': 'Artless',
#    'meaning': 'simple and natural; without cunning or deceit'},
#   {'word': 'Ascendancy',
#    'meaning': 'the state when one person or group has power over another'},
#   {'word': 'Ascertain', 'meaning': 'learn or discover with confidence'},
#   {'word': 'Ascetic',
#    'meaning': 'someone who practices self denial as a spiritual discipline'},
#   {'word': 'Ascribe', 'meaning': 'attribute or credit to'},
#   {'word': 'Askance', 'meaning': 'with suspicion or disapproval'},
#   {'word': 'Aspirant', 'meaning': 'an ambitious young person'},
#   {'word': 'Aspiration', 'meaning': 'a cherished desire'},
#   {'word': 'Aspire', 'meaning': 'have an ambitious plan or a lofty goal'},
#   {'word': 'Assail', 'meaning': 'attack someone physically or emotionally'},
#   {'word': 'Assay',
#    'meaning': 'a test of a substance to determine its components'},
#   {'word': 'Assent', 'meaning': 'agree or express agreement'},
#   {'word': 'Assert',
#    'meaning': 'declare or affirm solemnly and formally as true'},
#   {'word': 'Assiduous', 'meaning': 'marked by care and persistent effort'},
#   {'word': 'Assimilate', 'meaning': 'make alike'},
#   {'word': 'Assuage', 'meaning': 'provide physical relief, as from pain'},
#   {'word': 'Assumption', 'meaning': 'the act of taking something for granted'},
#   {'word': 'Assurance',
#    'meaning': 'a binding commitment to do or give or refrain from something'},
#   {'word': 'Asteroid',
#    'meaning': 'a small celestial body composed of rock and metal'},
#   {'word': 'Astral',
#    'meaning': 'being or relating to or resembling or emanating from stars'},
#   {'word': 'Astronomical',
#    'meaning': 'relating to the branch of physics studying celestial bodies'},
#   {'word': 'Astute', 'meaning': 'marked by practical hardheaded intelligence'},
#   {'word': 'Asunder', 'meaning': 'into parts or pieces'},
#   {'word': 'Asylum', 'meaning': 'a shelter from danger or hardship'},
#   {'word': 'Athwart',
#    'meaning': 'across the course, direction, or center line of a ship'},
#   {'word': 'Atone', 'meaning': 'turn away from sin or do penitence'},
#   {'word': 'Atrocity', 'meaning': 'an act of shocking cruelty'},
#   {'word': 'Attentive', 'meaning': 'taking heed'},
#   {'word': 'Attenuate',
#    'meaning': 'become weaker, in strength, value, or magnitude'},
#   {'word': 'Attest', 'meaning': 'provide evidence for'},
#   {'word': 'Attire',
#    'meaning': 'clothing of a distinctive style or for a particular occasion'},
#   {'word': 'Attribute',
#    'meaning': 'a quality belonging to or characteristic of an entity'},
#   {'word': 'Audacious', 'meaning': 'disposed to venture or take risks'},
#   {'word': 'Audacity', 'meaning': 'aggressive or outright boldness'},
#   {'word': 'Audit', 'meaning': 'examine carefully for accuracy'},
#   {'word': 'Augment', 'meaning': 'enlarge or increase'},
#   {'word': 'August', 'meaning': 'profoundly honored'},
#   {'word': 'Auspicious',
#    'meaning': 'indicating favorable circumstances and good luck'},
#   {'word': 'Austere', 'meaning': 'of a stern or strict bearing or demeanor'},
#   {'word': 'Austerity', 'meaning': 'excessive sternness'},
#   {'word': 'Authenticate',
#    'meaning': 'establish the undisputed credibility of something'},
#   {'word': 'Authoritative', 'meaning': 'of recognized power or excellence'},
#   {'word': 'Autocrat', 'meaning': 'a cruel and oppressive dictator'},
#   {'word': 'Auxiliary', 'meaning': 'furnishing added support'},
#   {'word': 'Avalanche',
#    'meaning': 'a slide of large masses of snow, ice and mud down a mountain'},
#   {'word': 'Avarice',
#    'meaning': 'reprehensible acquisitiveness; insatiable desire for wealth'},
#   {'word': 'Avatar',
#    'meaning': 'the manifestation of a Hindu deity in human or animal form'},
#   {'word': 'Avenge', 'meaning': 'take action in return for a perceived wrong'},
#   {'word': 'Aver',
#    'meaning': 'declare or affirm solemnly and formally as true'},
#   {'word': 'Averse', 'meaning': 'strongly opposed'},
#   {'word': 'Aversion', 'meaning': 'a feeling of intense dislike'},
#   {'word': 'Avert', 'meaning': 'turn away or aside'},
#   {'word': 'Avid', 'meaning': 'marked by active interest and enthusiasm'},
#   {'word': 'Avocation', 'meaning': 'an auxiliary activity'},
#   {'word': 'Avow',
#    'meaning': 'declare or affirm solemnly and formally as true'},
#   {'word': 'Awe',
#    'meaning': 'an overwhelming feeling of wonder or admiration'},
#   {'word': 'Awry', 'meaning': 'turned or twisted to one side'},
#   {'word': 'Axiom',
#    'meaning': 'a proposition that is not susceptible of proof or disproof'},
#   {'word': 'Azure', 'meaning': 'of a deep somewhat purplish blue color'},
#   {'word': 'Babble', 'meaning': 'utter meaningless sounds'},
#   {'word': 'Baffle', 'meaning': 'be a mystery or bewildering to'},
#   {'word': 'Bait', 'meaning': 'something used to lure fish or other animals'},
#   {'word': 'Baleful',
#    'meaning': 'threatening or foreshadowing evil or tragic developments'},
#   {'word': 'Balk', 'meaning': 'refuse to proceed or comply'},
#   {'word': 'Ballast',
#    'meaning': 'any heavy material used to stabilize a ship or airship'},
#   {'word': 'Balm',
#    'meaning': 'preparation applied externally as a remedy or for soothing'},
#   {'word': 'Balmy', 'meaning': 'mild and pleasant'},
#   {'word': 'Bane', 'meaning': 'something causing misery or death'},
#   {'word': 'Bank',
#    'meaning': 'financial institution that accepts deposits and lends money'},
#   {'word': 'Bar', 'meaning': 'a rigid piece of metal or wood'},
#   {'word': 'Barb',
#    'meaning': 'a point facing the main point making an arrowhead or spear'},
#   {'word': 'Bard', 'meaning': 'a lyric poet'},
#   {'word': 'Bargain',
#    'meaning': 'an agreement between parties fixing obligations of each'},
#   {'word': 'Barrage',
#    'meaning': 'the heavy fire of artillery to saturate an area'},
#   {'word': 'Barrister',
#    'meaning': 'a British lawyer who speaks in the higher courts of law'},
#   {'word': 'Base', 'meaning': 'lowest support of a structure'},
#   {'word': 'Bask',
#    'meaning': 'expose oneself to warmth and light, as for relaxation'},
#   {'word': 'Bastion',
#    'meaning': 'projecting part of a rampart or other fortification'},
#   {'word': 'Bate', 'meaning': 'moderate or restrain; lessen the force of'},
#   {'word': 'Battalion',
#    'meaning': 'an army unit consisting of a headquarters and companies'},
#   {'word': 'Bearing', 'meaning': "characteristic way of holding one's body"},
#   {'word': 'Beget', 'meaning': 'have children'},
#   {'word': 'Beguile', 'meaning': 'attract; cause to be enamored'},
#   {'word': 'Belated', 'meaning': 'after the expected or usual time'},
#   {'word': 'Beleaguer', 'meaning': 'annoy persistently'},
#   {'word': 'Belie', 'meaning': 'be in contradiction with'},
#   {'word': 'Belligerent',
#    'meaning': 'characteristic of an enemy or one eager to fight'},
#   {'word': 'Benediction',
#    'meaning': 'a blessing or ceremonial prayer invoking divine protection'},
#   {'word': 'Benefactor',
#    'meaning': 'a person who helps people or institutions'},
#   {'word': 'Beneficent', 'meaning': 'doing or producing good'},
#   {'word': 'Beneficial', 'meaning': 'promoting or enhancing well-being'},
#   {'word': 'Beneficiary',
#    'meaning': 'the recipient of funds or other advantages'},
#   {'word': 'Benefit', 'meaning': 'something that aids or promotes well-being'},
#   {'word': 'Benevolent',
#    'meaning': 'showing or motivated by sympathy and understanding'},
#   {'word': 'Benign', 'meaning': 'kind in disposition or manner'},
#   {'word': 'Bent', 'meaning': 'stooped (used of the back and knees)'},
#   {'word': 'Bequeath',
#    'meaning': "leave or give, especially by will after one's death"},
#   {'word': 'Bereaved', 'meaning': 'sorrowful through loss or deprivation'},
#   {'word': 'Bereavement',
#    'meaning': 'state of sorrow over the death or departure of a loved one'},
#   {'word': 'Bereft', 'meaning': 'lacking or deprived of something'},
#   {'word': 'Beseech', 'meaning': 'ask for or request earnestly'},
#   {'word': 'Beset', 'meaning': 'assail or attack on all sides'},
#   {'word': 'Besiege', 'meaning': 'surround so as to force to give up'},
#   {'word': 'Bestow', 'meaning': 'give as a gift'},
#   {'word': 'Betoken', 'meaning': 'be a signal for or a symptom of'},
#   {'word': 'Betray', 'meaning': 'deliver to an enemy by treachery'},
#   {'word': 'Betroth', 'meaning': 'give to in marriage'},
#   {'word': 'Beware',
#    'meaning': "be on one's guard; be cautious or wary about; be alert to"},
#   {'word': 'Bewitch', 'meaning': 'cast a spell over someone or something'},
#   {'word': 'Bicker', 'meaning': 'argue over petty things'},
#   {'word': 'Bid', 'meaning': 'propose a payment'},
#   {'word': 'Bigot',
#    'meaning': 'a prejudiced person who is intolerant of differing opinions'},
#   {'word': 'Bigotry', 'meaning': 'intolerance and prejudice'},
#   {'word': 'Billow', 'meaning': 'a large sea wave'},
#   {'word': 'Biting',
#    'meaning': 'causing a sharply painful or stinging sensation'},
#   {'word': 'Bitter', 'meaning': 'causing a sharp and acrid taste experience'},
#   {'word': 'Bivouac',
#    'meaning': 'temporary living quarters built by the army for soldiers'},
#   {'word': 'Bizarre',
#    'meaning': 'conspicuously or grossly unconventional or unusual'},
#   {'word': 'Blanch', 'meaning': 'turn pale, as if in fear'},
#   {'word': 'Bland', 'meaning': 'lacking taste or flavor or tang'},
#   {'word': 'Blare', 'meaning': 'make a loud noise'},
#   {'word': 'Blasphemous',
#    'meaning': 'grossly irreverent toward what is held to be sacred'},
#   {'word': 'Blasphemy', 'meaning': 'profane language '},
#   {'word': 'Blatant',
#    'meaning': 'without any attempt at concealment; completely obvious'},
#   {'word': 'Bleak', 'meaning': 'unpleasantly cold and damp'},
#   {'word': 'Blemish',
#    'meaning': 'a mark or flaw that spoils the appearance of something'},
#   {'word': 'Blight',
#    'meaning': 'any plant disease resulting in withering without rotting'},
#   {'word': 'Blighted',
#    'meaning': 'affected by something that prevents growth or prosperity'},
#   {'word': 'Bliss', 'meaning': 'a state of extreme happiness'},
#   {'word': 'Blithe', 'meaning': 'carefree and happy and lighthearted'},
#   {'word': 'Bloat',
#    'meaning': 'swelling of the intestinal tract of animals caused by gas'},
#   {'word': 'Blotch', 'meaning': 'an irregularly shaped spot'},
#   {'word': 'Blues', 'meaning': 'a state of depression'},
#   {'word': 'Bluff', 'meaning': 'a high steep bank'},
#   {'word': 'Blunder', 'meaning': 'an embarrassing mistake'},
#   {'word': 'Blunt', 'meaning': 'not sharp (used of a knife or other blade)'},
#   {'word': 'Blurt', 'meaning': 'utter impulsively'},
#   {'word': 'Blush', 'meaning': 'become rosy or reddish'},
#   {'word': 'Bluster', 'meaning': 'be gusty, as of wind'},
#   {'word': 'Bode', 'meaning': 'indicate by signs'},
#   {'word': 'Bog', 'meaning': 'wet spongy ground of decomposing vegetation'},
#   {'word': 'Boisterous', 'meaning': 'marked by exuberance and high spirits'},
#   {'word': 'Bolster', 'meaning': 'support and strengthen'},
#   {'word': 'Bolt',
#    'meaning': 'a screw that screws into a nut to form a fastener'},
#   {'word': 'Bombardment',
#    'meaning': 'an attack by dropping explosive devices'},
#   {'word': 'Boon',
#    'meaning': 'something that is desirable, favorable, or beneficial'},
#   {'word': 'Boor',
#    'meaning': 'a crude uncouth ill-bred person lacking refinement'},
#   {'word': 'Boost', 'meaning': 'increase'},
#   {'word': 'Bore',
#    'meaning': 'make a hole, especially with a pointed power or hand tool'},
#   {'word': 'Bouillon', 'meaning': 'a clear seasoned broth'},
#   {'word': 'Bound', 'meaning': 'confined by bonds'},
#   {'word': 'Bountiful', 'meaning': 'producing in abundance'},
#   {'word': 'Bourgeois', 'meaning': 'being of the property-owning class'},
#   {'word': 'Bout',
#    'meaning': 'a period of indeterminate length marked by some condition'},
#   {'word': 'Brag', 'meaning': 'show off'},
#   {'word': 'Braid', 'meaning': 'make by interlacing'},
#   {'word': 'Brand', 'meaning': 'a name given to a product or service'},
#   {'word': 'Brandish', 'meaning': 'move or swing back and forth'},
#   {'word': 'Bravado', 'meaning': 'a swaggering show of courage'},
#   {'word': 'Brave', 'meaning': 'possessing or displaying courage'},
#   {'word': 'Brawl',
#    'meaning': 'quarrel or fight noisily, angrily or disruptively'},
#   {'word': 'Brawn', 'meaning': 'the trait of possessing muscular strength'},
#   {'word': 'Brawny',
#    'meaning': 'possessing physical strength and weight; rugged and powerful'},
#   {'word': 'Brazen', 'meaning': 'unrestrained by convention or propriety'},
#   {'word': 'Breach',
#    'meaning': 'an opening, especially a gap in a dike or fortification'},
#   {'word': 'Breadth', 'meaning': 'the extent of something from side to side'},
#   {'word': 'Breed', 'meaning': 'cause to procreate (animals)'},
#   {'word': 'Brevity', 'meaning': 'the attribute of being short or fleeting'},
#   {'word': 'Bridle', 'meaning': 'headgear for a horse'},
#   {'word': 'Brim', 'meaning': 'the top edge of a vessel or other container'},
#   {'word': 'Brink', 'meaning': 'the edge of a steep place'},
#   {'word': 'Brisk', 'meaning': 'quick and energetic'},
#   {'word': 'Bristle', 'meaning': 'a stiff hair'},
#   {'word': 'Brittle', 'meaning': 'having little elasticity'},
#   {'word': 'Broach', 'meaning': 'bring up a topic for discussion'},
#   {'word': 'Brocade',
#    'meaning': 'thick expensive material with a raised pattern'},
#   {'word': 'Broil',
#    'meaning': 'cook by exposing to strong heat in a part of an oven'},
#   {'word': 'Brooch', 'meaning': 'a decorative pin'},
#   {'word': 'Brood',
#    'meaning': 'hang over, as of something threatening, dark, or menacing'},
#   {'word': 'Brook',
#    'meaning': 'a natural stream of water smaller than a river'},
#   {'word': 'Browse', 'meaning': 'feed as in a meadow or pasture'},
#   {'word': 'Bruise',
#    'meaning': 'a small injury that results in discoloration'},
#   {'word': 'Brunt',
#    'meaning': 'the main part, especially of a force or shock'},
#   {'word': 'Brusque', 'meaning': 'rudely abrupt or blunt in speech or manner'},
#   {'word': 'Buccaneer',
#    'meaning': 'someone who robs at sea or plunders the land from the sea'},
#   {'word': 'Buffet',
#    'meaning': 'piece of furniture that stands at the side of a dining room'},
#   {'word': 'Buffoon',
#    'meaning': 'a person who amuses others by ridiculous behavior'},
#   {'word': 'Bulge', 'meaning': 'swell or protrude outwards'},
#   {'word': 'Bulk', 'meaning': 'the property possessed by a large mass'},
#   {'word': 'Bullion', 'meaning': 'a mass of precious metal'},
#   {'word': 'Bully',
#    'meaning': 'discourage or frighten with threats or a domineering manner'},
#   {'word': 'Bulwark',
#    'meaning': 'an embankment built around a space for defensive purposes'},
#   {'word': 'Bungle', 'meaning': 'make a mess of, destroy, or ruin'},
#   {'word': 'Buoyant',
#    'meaning': 'tending to float on a liquid or rise in air or gas'},
#   {'word': 'Bureaucracy',
#    'meaning': 'a government administered primarily by nonelective officials'},
#   {'word': 'Burlesque',
#    'meaning': 'a theatrical entertainment of broad and earthy humor'},
#   {'word': 'Burnish', 'meaning': 'polish and make shiny'},
#   {'word': 'Bust',
#    'meaning': 'a sculpture of the head and shoulders of a person'},
#   {'word': 'Buttress', 'meaning': 'a support usually of stone or brick'},
#   {'word': 'Cabal',
#    'meaning': 'a clique that seeks power usually through intrigue'},
#   {'word': 'Cache', 'meaning': 'a hidden storage space'},
#   {'word': 'Cadence', 'meaning': 'the accent in a metrical foot of verse'},
#   {'word': 'Cadet',
#    'meaning': 'a military trainee (as at a military academy)'},
#   {'word': 'Cajole',
#    'meaning': 'influence or urge by gentle urging, caressing, or flattering'},
#   {'word': 'Calamity',
#    'meaning': 'an event resulting in great loss and misfortune'},
#   {'word': 'Calculated', 'meaning': 'carefully thought out in advance'},
#   {'word': 'Caliber', 'meaning': 'diameter of a tube or gun barrel'},
#   {'word': 'Callous', 'meaning': 'emotionally hardened'},
#   {'word': 'Calumny', 'meaning': 'a false accusation of an offense'},
#   {'word': 'Camp',
#    'meaning': 'temporary lodgings in the country for travelers'},
#   {'word': 'Candor',
#    'meaning': 'the quality of being honest and straightforward'},
#   {'word': 'Canine', 'meaning': 'a dog or related mammal'},
#   {'word': 'Canny',
#    'meaning': 'showing self-interest and shrewdness in dealing with others'},
#   {'word': 'Canon',
#    'meaning': 'a collection of books accepted as holy scripture'},
#   {'word': 'Cant', 'meaning': 'a slope in the turn of a road or track'},
#   {'word': 'Canter', 'meaning': 'a smooth three-beat gait'},
#   {'word': 'Canto', 'meaning': 'a major division of a long poem'},
#   {'word': 'Canvass', 'meaning': 'get opinions by asking specific questions'},
#   {'word': 'Capacious',
#    'meaning': 'large in the amount that can be contained'},
#   {'word': 'Capacity', 'meaning': 'capability to perform or produce'},
#   {'word': 'Capitulate', 'meaning': 'surrender under agreed conditions'},
#   {'word': 'Caprice', 'meaning': 'a sudden desire'},
#   {'word': 'Capricious',
#    'meaning': 'determined by chance or impulse rather than by necessity'},
#   {'word': 'Capsize', 'meaning': 'overturn accidentally'},
#   {'word': 'Caption',
#    'meaning': 'brief description accompanying an illustration'},
#   {'word': 'Cardinal', 'meaning': 'a vivid red color'},
#   {'word': 'Career',
#    'meaning': 'the particular occupation for which you are trained'},
#   {'word': 'Caricature',
#    'meaning': 'a representation of a person exaggerated for comic effect'},
#   {'word': 'Carnage',
#    'meaning': 'the savage and excessive killing of many people'},
#   {'word': 'Carnal', 'meaning': 'of or relating to the body or flesh'},
#   {'word': 'Carouse', 'meaning': 'engage in boisterous, drunken merrymaking'},
#   {'word': 'Carrion',
#    'meaning': 'the dead and rotting body of an animal; unfit for human food'},
#   {'word': 'Cascade',
#    'meaning': 'a small waterfall or series of small waterfalls'},
#   {'word': 'Caste', 'meaning': 'a hereditary social class among Hindus'},
#   {'word': 'Casual',
#    'meaning': 'without or seeming to be without plan or method; offhand'},
#   {'word': 'Casualty', 'meaning': 'someone injured or killed in an accident'},
#   {'word': 'Cataract',
#    'meaning': 'disease that involves the clouding of the lens of the eye'},
#   {'word': 'Catastrophe',
#    'meaning': "a sudden violent change in the earth's surface"},
#   {'word': 'Catechism',
#    'meaning': 'an elementary book summarizing the principles of a religion'},
#   {'word': 'Cater', 'meaning': 'give what is desired or needed'},
#   {'word': 'Caucus',
#    'meaning': 'meet to select a candidate or promote a policy'},
#   {'word': 'Causal', 'meaning': 'involving an entity that produces an effect'},
#   {'word': 'Caustic',
#    'meaning': 'capable of destroying or eating away by chemical action'},
#   {'word': 'Cavalcade',
#    'meaning': 'a procession of people traveling on horseback'},
#   {'word': 'Cavalier', 'meaning': 'showing a lack of concern or seriousness'},
#   {'word': 'Cede', 'meaning': 'give over'},
#   {'word': 'Celestial',
#    'meaning': 'relating to or inhabiting a divine heaven'},
#   {'word': 'Celibate', 'meaning': 'abstaining from sexual intercourse'},
#   {'word': 'Cemetery', 'meaning': 'a tract of land used for burials'},
#   {'word': 'Censor',
#    'meaning': 'a person authorized to suppress unacceptable material'},
#   {'word': 'Censure', 'meaning': 'harsh criticism or disapproval'},
#   {'word': 'Centurion', 'meaning': 'leader of soldiers in ancient Rome'},
#   {'word': 'Cerebral', 'meaning': 'of or relating to the brain'},
#   {'word': 'Ceremonious',
#    'meaning': 'characterized by pomp and stately display'},
#   {'word': 'Cessation', 'meaning': 'a stopping'},
#   {'word': 'Cession',
#    'meaning': 'the act of surrendering possession or control'},
#   {'word': 'Chafe', 'meaning': 'become or make sore by or as if by rubbing'},
#   {'word': 'Chaff',
#    'meaning': 'material consisting of seed coverings and pieces of stem'},
#   {'word': 'Chagrin', 'meaning': 'strong feelings of embarrassment'},
#   {'word': 'Chalice', 'meaning': 'a bowl-shaped drinking vessel'},
#   {'word': 'Champ',
#    'meaning': 'someone who has won first place in a competition'},
#   {'word': 'Champion',
#    'meaning': 'someone who has won first place in a competition'},
#   {'word': 'Championship',
#    'meaning': 'a competition at which a winner is chosen'},
#   {'word': 'Chancellor',
#    'meaning': 'the person who is head of state (in several countries)'},
#   {'word': 'Chant',
#    'meaning': 'a repetitive song in which syllables are assigned to a tone'},
#   {'word': 'Chaotic',
#    'meaning': 'completely unordered and unpredictable and confusing'},
#   {'word': 'Chapel', 'meaning': 'a place of worship that has its own altar'},
#   {'word': 'Chaplain',
#    'meaning': 'a member of the clergy ministering to some institution'},
#   {'word': 'Char', 'meaning': 'burn to charcoal'},
#   {'word': 'Charm',
#    'meaning': 'attractiveness that interests or pleases or stimulates'},
#   {'word': 'Chase', 'meaning': 'go after with the intent to catch'},
#   {'word': 'Chasm', 'meaning': "a deep opening in the earth's surface"},
#   {'word': 'Chaste', 'meaning': 'abstaining from unlawful sexual intercourse'},
#   {'word': 'Chasten', 'meaning': 'censure severely'},
#   {'word': 'Chastise', 'meaning': 'censure severely'},
#   {'word': 'Chattel', 'meaning': 'personal as opposed to real property'},
#   {'word': 'Chide', 'meaning': 'scold or reprimand severely or angrily'},
#   {'word': 'Chip',
#    'meaning': 'a small fragment of something broken off from the whole'},
#   {'word': 'Chisel',
#    'meaning': 'an edge tool with a flat steel blade with a cutting edge'},
#   {'word': 'Chivalrous',
#    'meaning': 'attentive and honorable like an ideal knight'},
#   {'word': 'Choice', 'meaning': 'the act of selecting'},
#   {'word': 'Choir',
#    'meaning': 'a chorus that sings as part of a religious ceremony'},
#   {'word': 'Chore', 'meaning': 'a specific piece of work required to be done'},
#   {'word': 'Chorus',
#    'meaning': 'actors who comment on the action in a classical Greek play'},
#   {'word': 'Chronic',
#    'meaning': 'long-lasting or characterized by long suffering'},
#   {'word': 'Chronicle',
#    'meaning': 'a record or narrative description of past events'},
#   {'word': 'Chuckle', 'meaning': 'a soft partly suppressed laugh'},
#   {'word': 'Cipher', 'meaning': 'a secret method of writing'},
#   {'word': 'Circuit',
#    'meaning': 'a journey or route all the way around a place or area'},
#   {'word': 'Circumscribe',
#    'meaning': 'draw a geometric figure around another figure'},
#   {'word': 'Circumvent', 'meaning': 'surround so as to force to give up'},
#   {'word': 'Cistern', 'meaning': 'a sac or cavity containing fluid'},
#   {'word': 'Citadel', 'meaning': 'a stronghold for shelter during a battle'},
#   {'word': 'Cite', 'meaning': 'make reference to'},
#   {'word': 'Civil',
#    'meaning': 'of or occurring between or among citizens of the state'},
#   {'word': 'Clairvoyant',
#    'meaning': 'someone who can perceive things not present to the senses'},
#   {'word': 'Clamber', 'meaning': 'climb awkwardly, as if by scrambling'},
#   {'word': 'Clamor', 'meaning': 'utter or proclaim insistently and noisily'},
#   {'word': 'Clandestine',
#    'meaning': 'conducted with or marked by hidden aims or methods'},
#   {'word': 'Clap', 'meaning': "strike one's hands together"},
#   {'word': 'Clasp', 'meaning': 'hold firmly and tightly'},
#   {'word': 'Cleave',
#    'meaning': 'separate or cut with a tool, such as a sharp instrument'},
#   {'word': 'Cleft', 'meaning': 'a long narrow opening'},
#   {'word': 'Clemency',
#    'meaning': 'leniency and compassion shown toward offenders'},
#   {'word': 'Clime',
#    'meaning': 'the weather in some location averaged over a period of time'},
#   {'word': 'Clip',
#    'meaning': 'a small fastener used to hold loose articles together'},
#   {'word': 'Clipper', 'meaning': 'scissors for cutting hair or finger nails'},
#   {'word': 'Clique',
#    'meaning': 'an exclusive circle of people with a common purpose'},
#   {'word': 'Cloister',
#    'meaning': 'residence that is a place of religious seclusion'},
#   {'word': 'Clot',
#    'meaning': 'a lump of material formed from the content of a liquid'},
#   {'word': 'Clout', 'meaning': '(boxing) a blow with the fist'},
#   {'word': 'Clown',
#    'meaning': 'a person who amuses others by ridiculous behavior'},
#   {'word': 'Coalition',
#    'meaning': 'the union of diverse things into one body or form or group'},
#   {'word': 'Coax',
#    'meaning': 'influence or urge by gentle urging, caressing, or flattering'},
#   {'word': 'Coerce', 'meaning': 'cause to do through pressure or necessity'},
#   {'word': 'Coercion', 'meaning': 'using force to cause something to occur'},
#   {'word': 'Cognizance', 'meaning': 'the state or act of having knowledge of'},
#   {'word': 'Cohere',
#    'meaning': 'cause to form a united, orderly, and consistent whole'},
#   {'word': 'Coin',
#    'meaning': 'a flat metal piece (usually a disc) used as money'},
#   {'word': 'Coincidence',
#    'meaning': 'the property of two things happening at the same time'},
#   {'word': 'Coincident', 'meaning': 'occurring or operating at the same time'},
#   {'word': 'Collaborate',
#    'meaning': 'work together on a common enterprise or project'},
#   {'word': 'Collate', 'meaning': 'assemble in proper sequence'},
#   {'word': 'Collateral',
#    'meaning': 'accompanying; following as a consequence'},
#   {'word': 'Collected', 'meaning': 'brought together in one place'},
#   {'word': 'Colloquy', 'meaning': 'formal conversation'},
#   {'word': 'Colossal',
#    'meaning': 'so great in size or force or extent as to elicit awe'},
#   {'word': 'Comeback', 'meaning': 'a quick reply to a question or remark'},
#   {'word': 'Comely', 'meaning': 'according with custom or propriety'},
#   {'word': 'Commemorate', 'meaning': 'call to remembrance'},
#   {'word': 'Commiserate', 'meaning': 'feel or express sympathy or compassion'},
#   {'word': 'Commodious', 'meaning': 'large and roomy'},
#   {'word': 'Commonplace', 'meaning': 'completely ordinary and unremarkable'},
#   {'word': 'Commonwealth',
#    'meaning': 'a political system in which power lies in a body of citizens'},
#   {'word': 'Communal', 'meaning': 'for or by a group rather than individuals'},
#   {'word': 'Commune', 'meaning': 'share or interact intimately with'},
#   {'word': 'Compact',
#    'meaning': 'closely and firmly united or packed together'},
#   {'word': 'Compartment',
#    'meaning': 'a partitioned section within a larger enclosed area'},
#   {'word': 'Compassion',
#    'meaning': "a deep awareness of and sympathy for another's suffering"},
#   {'word': 'Compatible',
#    'meaning': 'able to exist and perform in harmonious combination'},
#   {'word': 'Compelling',
#    'meaning': 'capable of arousing and holding the attention'},
#   {'word': 'Compilation', 'meaning': 'the act of putting together '},
#   {'word': 'Compile', 'meaning': 'get or gather together'},
#   {'word': 'Complacency',
#    'meaning': 'the feeling you have when you are satisfied with yourself'},
#   {'word': 'Complacent',
#    'meaning': "contented to a fault with oneself or one's actions"},
#   {'word': 'Complaisant',
#    'meaning': 'showing a cheerful willingness to do favors for others'},
#   {'word': 'Complement',
#    'meaning': 'something added to embellish or make perfect'},
#   {'word': 'Compliance',
#    'meaning': 'the act of submitting, usually surrendering power to another'},
#   {'word': 'Complicity',
#    'meaning': 'guilt as a confederate in a crime or offense'},
#   {'word': 'Component',
#    'meaning': 'one of the individual parts making up a larger entity'},
#   {'word': 'Composure', 'meaning': 'steadiness of mind under stress'},
#   {'word': 'Compound',
#    'meaning': 'a whole formed by a union of two or more elements or parts'},
#   {'word': 'Comprehend', 'meaning': 'get the meaning of something'},
#   {'word': 'Comprehensive', 'meaning': 'including all or everything'},
#   {'word': 'Compress', 'meaning': 'squeeze or press together'},
#   {'word': 'Comprise', 'meaning': 'be made of'},
#   {'word': 'Compromise',
#    'meaning': 'an accommodation in which both sides make concessions'},
#   {'word': 'Compulsion', 'meaning': 'using force to cause something to occur'},
#   {'word': 'Compulsory', 'meaning': 'required by rule'},
#   {'word': 'Compunction',
#    'meaning': 'a feeling of deep regret, usually for some misdeed'},
#   {'word': 'Compute', 'meaning': 'make a mathematical calculation'},
#   {'word': 'Concave', 'meaning': 'curving inward'},
#   {'word': 'Concede', 'meaning': 'give over'},
#   {'word': 'Conceit', 'meaning': 'the trait of being unduly vain'},
#   {'word': 'Conception', 'meaning': 'the creation of something in the mind'},
#   {'word': 'Concerted',
#    'meaning': 'involving the joint activity of two or more'},
#   {'word': 'Concession', 'meaning': 'the act of yielding'},
#   {'word': 'Conciliate',
#    'meaning': 'gain the good will of or cause to be more favorably inclined'},
#   {'word': 'Conciliatory', 'meaning': 'making or willing to make concessions'},
#   {'word': 'Concise', 'meaning': 'expressing much in few words'},
#   {'word': 'Conclave', 'meaning': 'a confidential or secret meeting'},
#   {'word': 'Conclusive', 'meaning': 'forming a decisive end or resolution'},
#   {'word': 'Concoct', 'meaning': 'make something by mixing'},
#   {'word': 'Concur', 'meaning': 'happen simultaneously'},
#   {'word': 'Condescend', 'meaning': 'behave in a patronizing manner'},
#   {'word': 'Condole',
#    'meaning': "express one's sympathy on the occasion of someone's death"},
#   {'word': 'Condone', 'meaning': 'excuse, overlook, or make allowances for'},
#   {'word': 'Conducive',
#    'meaning': 'tending to bring about; being partly responsible for'},
#   {'word': 'Confidant', 'meaning': 'someone to whom private matters are told'},
#   {'word': 'Confide', 'meaning': 'reveal in private'},
#   {'word': 'Confidence', 'meaning': 'belief in yourself and your abilities'},
#   {'word': 'Confidential', 'meaning': 'given in secret'},
#   {'word': 'Confine', 'meaning': 'place limits on'},
#   {'word': 'Confiscate',
#    'meaning': 'take temporary possession of a security by legal authority'},
#   {'word': 'Conflagration', 'meaning': 'a very intense and uncontrolled fire'},
#   {'word': 'Conformity',
#    'meaning': 'correspondence in form, type, or appearance'},
#   {'word': 'Confound', 'meaning': 'be confusing or perplexing to'},
#   {'word': 'Congenial', 'meaning': 'suitable to your needs'},
#   {'word': 'Conglomerate', 'meaning': 'collect or gather'},
#   {'word': 'Conjecture',
#    'meaning': 'believe especially on uncertain or tentative grounds'},
#   {'word': 'Conjugal',
#    'meaning': 'relating to the relationship between a wife and husband'},
#   {'word': 'Conjure', 'meaning': 'summon into action or bring into existence'},
#   {'word': 'Connoisseur', 'meaning': 'an expert able to appreciate a field'},
#   {'word': 'Conscientious',
#    'meaning': 'characterized by extreme care and great effort'},
#   {'word': 'Conscript', 'meaning': 'enroll into service compulsorily'},
#   {'word': 'Consecrate',
#    'meaning': 'give entirely to a specific person, activity, or cause'},
#   {'word': 'Consensus',
#    'meaning': 'agreement in the judgment reached by a group as a whole'},
#   {'word': 'Consequential', 'meaning': 'having important issues or results'},
#   {'word': 'Conservatory',
#    'meaning': 'a schoolhouse with special facilities for fine arts'},
#   {'word': 'Consign',
#    'meaning': 'give over to another for care or safekeeping'},
#   {'word': 'Consistency',
#    'meaning': 'uniformity or stability in arrangement, behavior, or quality'},
#   {'word': 'Console', 'meaning': 'give moral or emotional strength to'},
#   {'word': 'Consolidation', 'meaning': 'combining into a solid mass'},
#   {'word': 'Consonant', 'meaning': 'a speech sound that is not a vowel'},
#   {'word': 'Consort', 'meaning': 'keep company with'},
#   {'word': 'Conspiracy',
#    'meaning': 'a plot to carry out some harmful or illegal act'},
#   {'word': 'Conspire',
#    'meaning': 'act in agreement and in secret towards a deceitful purpose'},
#   {'word': 'Consternation',
#    'meaning': 'sudden shock or dismay that causes confusion'},
#   {'word': 'Constituency',
#    'meaning': 'the body of voters who elect a representative for their area'},
#   {'word': 'Constituent',
# ...
#   {'word': 'Obfuscate', 'meaning': 'make obscure or unclear'},
#   {'word': 'Objurgation', 'meaning': 'rebuking a person harshly'},
#   {'word': 'Obsidian',
#    'meaning': 'glass formed by the cooling of lava without crystallization'},
#   {'word': 'Obstetrician',
#    'meaning': 'a physician specializing in childbirth'},
#   {'word': 'Occlude', 'meaning': 'block passage through'},
#   {'word': 'Oculist',
#    'meaning': 'a person skilled in testing for defects of vision'},
#   {'word': 'Odyssey', 'meaning': 'a long wandering and eventful journey'},
#   {'word': 'Omnivorous', 'meaning': 'feeding on both plants and animals'},
#   {'word': 'Onomatopoeia',
#    'meaning': 'using words that imitate the sound they denote'},
#   {'word': 'Onus', 'meaning': 'a burdensome or difficult concern'},
#   {'word': 'Opalescent',
#    'meaning': 'having a play of lustrous rainbow colors'},
#   {'word': 'Optician',
#    'meaning': 'a worker who makes glasses for remedying defects of vision'},
#   {'word': 'Optometrist',
#    'meaning': 'a person skilled in testing for defects of vision'},
#   {'word': 'Orison', 'meaning': 'reverent petition to a deity'},
#   {'word': 'Ornery', 'meaning': 'having a difficult and contrary disposition'},
#   {'word': 'Ornithologist', 'meaning': 'a scientist who studies birds'},
#   {'word': 'Orotund', 'meaning': 'overly formal and pompous in style'},
#   {'word': 'Osseous', 'meaning': 'composed of or containing bone'},
#   {'word': 'Ossify', 'meaning': 'become bony'},
#   {'word': 'Ostracize', 'meaning': 'expel from a community or group'},
#   {'word': 'Outmoded', 'meaning': 'no longer in fashion'},
#   {'word': 'Overblown', 'meaning': 'puffed up with vanity'},
#   {'word': 'Pachyderm',
#    'meaning': 'a large mammal with thick skin, such as an elephant or hippo'},
#   {'word': 'Palimpsest',
#    'meaning': 'a manuscript on which more than one text has been written'},
#   {'word': 'Palliation',
#    'meaning': 'easing the severity of a pain without removing the cause'},
#   {'word': 'Panache', 'meaning': 'distinctive and stylish elegance'},
#   {'word': 'Parameter',
#    'meaning': 'a constant in the equation of a curve that can be varied'},
#   {'word': 'Parlous', 'meaning': 'fraught with danger'},
#   {'word': 'Parquet', 'meaning': 'a floor made of a patterned wood inlay'},
#   {'word': 'Pastiche',
#    'meaning': 'a work of art that imitates the style of some previous work'},
#   {'word': 'Patina',
#    'meaning': 'a fine coating of oxide on the surface of a metal'},
#   {'word': 'Peccadillo', 'meaning': 'a petty misdeed'},
#   {'word': 'Pejorative', 'meaning': 'expressing disapproval'},
#   {'word': 'Penumbra',
#    'meaning': 'a region of light shadow around the darkest part of a shadow'},
#   {'word': 'Penurious', 'meaning': 'excessively unwilling to spend'},
#   {'word': 'Peregrination', 'meaning': 'traveling or wandering around'},
#   {'word': 'Perigee',
#    'meaning': 'the nearest point in an orbit around the Earth'},
#   {'word': 'Peripatetic', 'meaning': 'traveling especially on foot'},
#   {'word': 'Permeable',
#    'meaning': 'allowing fluids or gases to pass or diffuse through'},
#   {'word': 'Permissive', 'meaning': 'not strict in discipline'},
#   {'word': 'Persiflage', 'meaning': 'light teasing'},
#   {'word': 'Personable', 'meaning': 'pleasant in manner and appearance'},
#   {'word': 'Perspicacious',
#    'meaning': 'mentally acute or penetratingly discerning'},
#   {'word': 'Perspicuity',
#    'meaning': 'clarity as a consequence of being easily understandable'},
#   {'word': 'Pharisaical', 'meaning': 'excessively or hypocritically pious'},
#   {'word': 'Philanderer', 'meaning': 'a man who likes many women'},
#   {'word': 'Philatelist',
#    'meaning': 'a collector and student of postage stamps'},
#   {'word': 'Philistine',
#    'meaning': 'a person who is uninterested in intellectual pursuits'},
#   {'word': 'Phobia',
#    'meaning': 'an anxiety disorder characterized by irrational fear'},
#   {'word': 'Phylum',
#    'meaning': 'the major taxonomic group of animals and plants'},
#   {'word': 'Picaresque',
#    'meaning': '(of fiction) involving clever rogues or adventurers'},
#   {'word': 'Piebald',
#    'meaning': 'having sections or patches colored differently and brightly'},
#   {'word': 'Piscatorial',
#    'meaning': 'relating to or characteristic of the activity of fishing'},
#   {'word': 'Plagiarize',
#    'meaning': "take without referencing from someone's writing or speech"},
#   {'word': 'Plangent',
#    'meaning': 'loud and resounding, often in a mournful way'},
#   {'word': 'Plasticity',
#    'meaning': 'the property of being physically malleable'},
#   {'word': 'Platonic', 'meaning': 'free from physical desire'},
#   {'word': 'Podiatrist', 'meaning': 'a specialist in care for the feet'},
#   {'word': 'Polygamist',
#    'meaning': 'someone married to two or more people at the same time'},
#   {'word': 'Pomposity',
#    'meaning': 'lack of elegance from being puffed up with vanity'},
#   {'word': 'Poseur',
#    'meaning': 'a person who habitually pretends to be something he is not'},
#   {'word': 'Postmortem', 'meaning': 'occurring or done after death'},
#   {'word': 'Postprandial', 'meaning': 'following a meal, especially dinner'},
#   {'word': 'Potable', 'meaning': 'suitable for drinking'},
#   {'word': 'Potpourri',
#    'meaning': 'a collection containing a variety of sorts of things'},
#   {'word': 'Pragmatist',
#    'meaning': 'an adherent of a theory of observable practical consequences'},
#   {'word': 'Precipitant',
#    'meaning': 'done with very great haste and without due deliberation'},
#   {'word': 'Precis',
#    'meaning': 'a sketchy summary of the main points of an argument'},
#   {'word': 'Preempt',
#    'meaning': 'acquire for oneself before others can do so'},
#   {'word': 'Prefigure',
#    'meaning': 'indicate by signs; be an early indication of'},
#   {'word': 'Prehensile',
#    'meaning': 'adapted for grasping especially by wrapping around an object'},
#   {'word': 'Premonitory', 'meaning': 'warning of future misfortune'},
#   {'word': 'Primogeniture',
#    'meaning': 'right of inheritance belonging exclusively to the eldest son'},
#   {'word': 'Primp', 'meaning': 'dress or groom with elaborate care'},
#   {'word': 'Prolixity', 'meaning': 'boring verbosity'},
#   {'word': 'Propellant',
#    'meaning': 'any substance that moves forward with force'},
#   {'word': 'Prophylactic',
#    'meaning': 'preventing or contributing to the prevention of disease'},
#   {'word': 'Propinquity', 'meaning': 'the property of being close together'},
#   {'word': 'Propulsive',
#    'meaning': 'having the power to move forward with force'},
#   {'word': 'Proscenium',
#    'meaning': 'the part of a stage between the curtain and the orchestra '},
#   {'word': 'Proselytize',
#    'meaning': 'convert or try to convert someone to another religion'},
#   {'word': 'Prosody',
#    'meaning': 'the study of poetic meter and the art of versification'},
#   {'word': 'Protean', 'meaning': 'taking on different forms'},
#   {'word': 'Provenance',
#    'meaning': 'where something originated or was nurtured'},
#   {'word': 'Prurient', 'meaning': 'characterized by lust'},
#   {'word': 'Psychopathic',
#    'meaning': 'suffering from an undiagnosed mental disorder'},
#   {'word': 'Psychosomatic',
#    'meaning': 'used of illness or symptoms resulting from neurosis'},
#   {'word': 'Pterodactyl', 'meaning': 'extinct flying reptile'},
#   {'word': 'Pugnacity', 'meaning': 'a natural disposition to be hostile'},
#   {'word': 'Pulchritude', 'meaning': 'physical beauty, especially of a woman'},
#   {'word': 'Purview',
#    'meaning': 'the range of interest or activity that can be anticipated'},
#   {'word': 'Putative', 'meaning': 'purported'},
#   {'word': 'Putrescent', 'meaning': 'in a state of decay or decomposition'},
#   {'word': 'Pyromaniac',
#    'meaning': 'a person with a mania for setting things on fire'},
#   {'word': 'Queasy', 'meaning': 'causing or able to cause nausea'},
#   {'word': 'Quiescence',
#    'meaning': 'a state of possibly temporary inaction or dormancy'},
#   {'word': 'Quisling',
#    'meaning': 'someone who collaborates with an enemy occupying force'},
#   {'word': 'Quotidian', 'meaning': 'found in the ordinary course of events'},
#   {'word': 'Rabies',
#    'meaning': 'an acute viral disease transmitted by animal bites'},
#   {'word': 'Raconteur', 'meaning': 'a person skilled in telling anecdotes'},
#   {'word': 'Rapprochement',
#    'meaning': 'the reestablishing of cordial relations'},
#   {'word': 'Raspy', 'meaning': 'unpleasantly harsh or grating in sound'},
#   {'word': 'Ratiocination',
#    'meaning': 'the proposition arrived at by logical reasoning'},
#   {'word': 'Rationalization',
#    'meaning': 'the process of making something seem consistent with reason'},
#   {'word': 'Recidivism', 'meaning': 'habitual relapse into crime'},
#   {'word': 'Refulgent', 'meaning': 'radiating or as if radiating light'},
#   {'word': 'Reintegrate', 'meaning': 'incorporate, combine, or unify again'},
#   {'word': 'Renege', 'meaning': 'fail to fulfill a promise or obligation'},
#   {'word': 'Responsiveness', 'meaning': 'the quality of reacting quickly'},
#   {'word': 'Retraction',
#    'meaning': 'a disavowal or taking back of a previous assertion'},
#   {'word': 'Rhapsodize', 'meaning': 'say with great enthusiasm'},
#   {'word': 'Rheumy', 'meaning': 'watery and red, as of the eyes'},
#   {'word': 'Risible', 'meaning': 'arousing or provoking laughter'},
#   {'word': 'Rotundity', 'meaning': 'the roundness of a 3-dimensional object'},
#   {'word': 'Rubicund', 'meaning': 'having a healthy reddish color'},
#   {'word': 'Runic',
#    'meaning': 'relating to characters from an ancient alphabet'},
#   {'word': 'Rusticate',
#    'meaning': 'live in the country and lead a pastoral life'},
#   {'word': 'Saboteur',
#    'meaning': 'someone who deliberately destroys or disrupts something'},
#   {'word': 'Saccharine', 'meaning': 'overly sweet'},
#   {'word': 'Sacrosanct',
#    'meaning': 'treated as if holy and kept free from violation or criticism'},
#   {'word': 'Sadistic',
#    'meaning': 'deriving pleasure from inflicting pain on another'},
#   {'word': 'Salacious',
#    'meaning': 'suggestive of or tending to moral looseness'},
#   {'word': 'Sang-froid',
#    'meaning': 'great coolness and composure under strain'},
#   {'word': 'Sapid', 'meaning': 'full of flavor'},
#   {'word': 'Sartorial', 'meaning': 'of or relating to tailoring or clothing'},
#   {'word': 'Savoir-faire', 'meaning': 'social skill'},
#   {'word': 'Schematic',
#    'meaning': 'represented in simplified or symbolic form'},
#   {'word': 'Scotch',
#    'meaning': 'hinder or prevent, as an effort, plan, or desire'},
#   {'word': 'Screed', 'meaning': 'a long, tedious rant'},
#   {'word': 'Seamy', 'meaning': 'morally degraded'},
#   {'word': 'Senescence', 'meaning': 'the property characteristic of old age'},
#   {'word': 'Senility', 'meaning': 'the state of being infirm with age'},
#   {'word': 'Sensitization',
#    'meaning': ' the process of becoming highly responsive to situations '},
#   {'word': 'Serendipity',
#    'meaning': 'good luck in making unexpected and fortunate discoveries'},
#   {'word': 'Shibboleth',
#    'meaning': 'a favorite saying of a sect or political group'},
#   {'word': 'Shyster',
#    'meaning': 'a person who uses unscrupulous or unethical methods'},
#   {'word': 'Sibylline',
#    'meaning': 'resembling or characteristic of a prophet or prophecy'},
#   {'word': 'Sidereal',
#    'meaning': 'of or relating to the stars or constellations'},
#   {'word': 'Simian', 'meaning': 'relating to or resembling an ape'},
#   {'word': 'Simplistic',
#    'meaning': 'characterized by extreme and misleading lack of complexity'},
#   {'word': 'Skimp', 'meaning': 'work hastily or carelessly'},
#   {'word': 'Skinflint',
#    'meaning': 'a selfish person who is unwilling to give or spend'},
#   {'word': 'Slapdash', 'meaning': 'marked by great carelessness'},
#   {'word': 'Sleazy', 'meaning': 'morally degraded'},
#   {'word': 'Solecism', 'meaning': 'a socially awkward or tactless act'},
#   {'word': 'Somatic',
#    'meaning': 'characteristic of the body as opposed to the mind or spirit'},
#   {'word': 'Somnambulist',
#    'meaning': 'someone who walks about in their sleep'},
#   {'word': 'Soporific', 'meaning': 'inducing sleep'},
#   {'word': 'Spartan',
#    'meaning': 'unsparing and uncompromising in discipline or judgment'},
#   {'word': 'Spatula', 'meaning': 'a hand tool with a thin flexible blade'},
#   {'word': 'Spoilsport',
#    'meaning': 'someone who ruins the pleasure of others'},
#   {'word': 'Spoonerism',
#    'meaning': 'transposition of initial consonants in a pair of words'},
#   {'word': 'Stipple', 'meaning': 'engrave by means of dots and flicks'},
#   {'word': 'Stodgy',
#    'meaning': 'excessively conventional and unimaginative and hence dull'},
#   {'word': 'Subliminal',
#    'meaning': 'below the threshold of conscious perception'},
#   {'word': 'Summation',
#    'meaning': 'calculating the total of two or more numbers'},
#   {'word': 'Sumptuary',
#    'meaning': 'regulating or controlling expenditure or personal behavior'},
#   {'word': 'Supernal', 'meaning': 'of heaven or the spirit'},
#   {'word': 'Supposititious',
#    'meaning': 'based primarily on surmise rather than adequate evidence'},
#   {'word': 'Surcease', 'meaning': 'a stopping'},
#   {'word': 'Sycophantic', 'meaning': 'attempting to win favor by flattery'},
#   {'word': 'Synchronous', 'meaning': 'occurring or existing at the same time'},
#   {'word': 'Tactile',
#    'meaning': 'of or relating to or proceeding from the sense of touch'},
#   {'word': 'Tatterdemalion', 'meaning': 'a dirty shabbily clothed person'},
#   {'word': 'Tautological',
#    'meaning': 'characterized by unnecessary repetition'},
#   {'word': 'Tautology', 'meaning': 'useless repetition'},
#   {'word': 'Tendentious',
#    'meaning': 'having a strong bias, especially a controversial one'},
#   {'word': 'Tenebrous', 'meaning': 'dark and gloomy'},
#   {'word': 'Termagant', 'meaning': 'a scolding, nagging, bad-tempered woman'},
#   {'word': 'Tessellated',
#    'meaning': 'decorated with small pieces of colored glass or stone'},
#   {'word': 'Torque', 'meaning': 'a twisting force'},
#   {'word': 'Tortilla',
#    'meaning': 'thin unleavened pancake made from cornmeal or wheat flour'},
#   {'word': 'Troglodyte', 'meaning': 'one who lives in solitude'},
#   {'word': 'Tumid',
#    'meaning': 'abnormally distended especially by fluids or gas'},
#   {'word': 'Turpitude',
#    'meaning': 'a corrupt or depraved or degenerate act or practice'},
#   {'word': 'Tutelary', 'meaning': 'providing protective supervision'},
#   {'word': 'Unguent',
#    'meaning': 'preparation applied externally as a remedy or for soothing'},
#   {'word': 'Ursine', 'meaning': 'of or relating to or similar to bears'},
#   {'word': 'Usufruct',
#    'meaning': "a legal right to use and profit from someone else's property"},
#   {'word': 'Utopia', 'meaning': 'ideally perfect state'},
#   {'word': 'Uxorious',
#    'meaning': 'foolishly fond of or submissive to your wife'},
#   {'word': 'Vainglorious', 'meaning': 'feeling self-importance'},
#   {'word': 'Valedictory', 'meaning': 'a farewell oration'},
#   {'word': 'Venturous', 'meaning': 'disposed to take risks'},
#   {'word': 'Verbiage', 'meaning': 'overabundance of words'},
#   {'word': 'Verbose', 'meaning': 'using or containing too many words'},
#   {'word': 'Verdigris',
#    'meaning': 'a green patina that forms on copper or brass or bronze'},
#   {'word': 'Vertex', 'meaning': 'the highest point of something'},
#   {'word': 'Vertiginous',
#    'meaning': 'having or causing a whirling sensation; liable to falling'},
#   {'word': 'Virago', 'meaning': 'a noisy or scolding or domineering woman'},
#   {'word': 'Vitreous',
#    'meaning': 'relating to or resembling or derived from glass'},
#   {'word': 'Vitriolic', 'meaning': 'harsh, bitter, or malicious in tone'},
#   {'word': 'Vituperative', 'meaning': 'marked by harshly abusive criticism'},
#   {'word': 'Waggish', 'meaning': 'witty or joking'},
#   {'word': 'Wastrel', 'meaning': 'someone who squanders resources or time'},
#   {'word': 'Wizardry', 'meaning': 'exceptional creative ability'},
#   {'word': 'Xenophobia', 'meaning': 'a fear of foreigners or strangers'},
#   {'word': 'Yokel',
#    'meaning': 'a person who is not intelligent or interested in culture'}]}

# %%
pickle.dump(pickle_storage,open('difficulty_to_words_map.pkl','wb'))

# %%
try:
    all_words = pickle.load(open('really_all_words.pkl','rb'))
except FileNotFoundError:
    all_words = []
len(all_words)
# Out:
# 3626

# %%
base_dir = './raw_words'
file_list = os.listdir(base_dir)
file_list
# Out:
# ['List01.txt',
#  'word_list_magoosh.txt',
#  'word_list_pylike.txt',
#  'List05.txt',
#  'List09.txt',
#  'List08.txt',
#  'List04.txt',
#  'List07.txt',
#  'List02.txt',
#  'word_list_essential.txt',
#  'words_with_meanings.json',
#  'List06.txt',
#  'List03.txt',
#  'word_freq.json',
#  'word_list.txt']

# %%
#List0X.txt
list_type_files = [filename for filename in file_list if 'List' in filename]
for file in list_type_files:
    with open(os.path.join(base_dir,file)) as f:
        output = [x for x in f.read().splitlines() if x!='' and x.startswith('/')==False]
    words = [line.strip().lower() for line in output if '.' not in line]
    all_words.extend(words)

# %%
#word_list_magoosh.txt
with open(os.path.join(base_dir,'word_list_magoosh.txt')) as f:
    output = f.read().splitlines()
    magoosh_words = [line.strip().lower() for line in output]
all_words.extend(magoosh_words)

# %%
#word_list.txt
with open(os.path.join(base_dir,'word_list.txt')) as f:
#     output = [x.strip() for x in f.read().splitlines() if len(x)!=0 and '(' not in x and ')' not in x and '*' not in x and '-' not in x and ':' not in x and '/' not in x]
    my_new_word_list = [x.strip().lower() for x in f.read().splitlines() if len(x.strip().split())==1 and '(' not in x and ')' not in x and  '-' not in x and '*' not in x and '.' not in x and not x.isupper()]
all_words.extend(my_new_word_list)

# %%
#words_with_meanings.json
with open(os.path.join(base_dir,'words_with_meanings.json')) as f:
    output = json.load(f)
for key in output:
    all_words.extend([x['word'].lower() for x in output[key]])

# %%
#word_freq.json
with open(os.path.join(base_dir,'word_freq.json')) as f:
    output = json.load(f)
fresher_word_list = [x for x in list(output.keys()) if len(x.split())==1]
all_words.extend(fresher_word_list)

# %%
#word_list_essential.txt
with open(os.path.join(base_dir,'word_list_essential.txt')) as f:
    my_new_word_list_essential = [x.strip().lower() for x in f.read().splitlines() if len(x.strip().split())==1 and '(' not in x and ')' not in x and  '-' not in x and '*' not in x and '.' not in x and not x.isupper()]
all_words.extend(my_new_word_list_essential)

# %%
#word_list_pylike.txt
with open(os.path.join(base_dir,'word_list_pylike.txt')) as f:
    pylike_word_list = [x.strip().split('\'')[1] for x in f.read().splitlines() if 'Word(' in x and len(x.strip().split('\''))>1]
all_words.extend([x.strip().lower() for x in pylike_word_list])

# %%
# TODO: This has frequency data

import requests
request_text = requests.get('https://www.vocabulary.com/lists/128536').text
try: 
    from BeautifulSoup import BeautifulSoup
except ImportError:
    from bs4 import BeautifulSoup
html = request_text
parsed_html = BeautifulSoup(html)
html_list = list(parsed_html.body.find_all('li', attrs={'class':'entry learnable'}))

large_af_word_list = [str(x).split('\"')[9] for x in html_list]
all_words.extend(large_af_word_list)

# %%
pickle.dump(list(set([word.lower() for word in all_words])),open('really_all_words.pkl','wb'))
all_words = pickle.load(open('really_all_words.pkl','rb'))
len(all_words)
# Out:
# 6024

# %%
split_list = [str(x).split("\"") for x in html_list]
data = []
set_of_words = set()
for item in split_list:
    datapoint= {}
    datapoint['freq'] = float(item[3])
    datapoint['word'] = item[9].strip().lower()
    datapoint['meaning'] = item[16].split('>')[1].split('<')[0]
    before = len(set_of_words)
    set_of_words.add(datapoint['word'])
    after = len(set_of_words)
    if after==before:
        print('Duplicate',datapoint['word'],datapoint['word'] in set_of_words)
        continue
    data.append(datapoint)
pickle.dump(data,open('all_words_with_freq_and_meaning.pkl','wb'))
# Out:
# Duplicate appurtenance True
# Duplicate bloat True
# Duplicate cavil True
# Duplicate loquacious True
# Duplicate purport True
# Duplicate qualm True
# Duplicate vie True

# %%
# Commented code
#     word_dict = {}
#     value = []

#         word_dict[line] = tuple(value)
#         value = []
#         continue
#     tokens = line.split('.')
#     value.extend([x.strip() for x in tokens])
